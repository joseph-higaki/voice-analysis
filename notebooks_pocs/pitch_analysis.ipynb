# %%
import matplotlib.pyplot as plt
#import notebooks_pocs 
#from notebooks_pocs.voice_utils import *
import seaborn as sns
import pandas as pd
import numpy as np

sns.set_theme()

# %%
    #plt.figure()
    snd = parselmouth.Sound("/workspaces/voice-analysis/notebooks_pocs/audio/low.wav")


#def draw_pitch(plt, snd):
    pitch = snd.to_pitch()
    # Extract selected pitch contour, and
    # replace unvoiced samples by NaN to not plot
    pitch_values = pitch.selected_array['frequency']

    pitch_values[pitch_values==0] = np.nan
    plt.plot(pitch.xs(), pitch_values, 'o', markersize=5, color='w')
    plt.plot(pitch.xs(), pitch_values, '.', markersize=1)            
    plt.ylim(0, np.nanmax(pitch_values))  
    
    plt.ylabel("fundamental frequency [Hz]")
    plt.xlabel("time [secs]")
    df = pd.DataFrame(pitch.selected_array['frequency'])
    
    plt.show()

# %%
pitch2 = snd.to_pitch()
    
freqs = pitch2.selected_array['frequency']

# %%
freqs
#type(freqs)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
np.nanmax(freqs)
# Out:
# np.float64(447.4033545486049)

# %%
freqs[freqs==70] = np.nan

# %%
plt.figure()
snd = parselmouth.Sound("/workspaces/voice-analysis/notebooks_pocs/audio/low.wav")
draw_pitch(plt, snd)
plt.show()
